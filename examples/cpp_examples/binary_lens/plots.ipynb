# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl

mpl.rc('font',**{'family':'serif','serif':['Palatino']})
mpl.rc('text', usetex=True)
mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams['axes.titlesize'] = 20

# %matplotlib inline

# Better looking figures
# %config InlineBackend.figure_format = 'retina'

# %%
# !make clean
# !make
# !./main
# Out:
# rm -f *.o *~ main
# g++  -std=c++11 -O3 -Wall -Wextra -pedantic -DNDEBUG  -I/home/fran/drive/projects/VBBinaryLensing -o main main.cpp -L/home/fran/drive/projects/VBBinaryLensing -lVBB
# Successfully compiled.

# %%
data = np.genfromtxt('output.csv', delimiter=',')
caustics = np.genfromtxt('caustics.csv', delimiter=',')

# %%
fig, ax = plt.subplots(figsize=(12,7))
ax.plot(data[:, 0], data[:, -1], 'k-')
ax.grid(True)

ax2 = fig.add_axes([.54, .44, .4, .4], aspect=1)
ax2.plot(caustics[:, 0], caustics[:, 1], 'k-')
line, = ax2.plot(data[:, 1], data[:, 2], 'k--')
# ax2.arrow((data[-1, 1] + data[0, 1])/2, (data[-1, 2] + data[0, 2])/2, 
#           (data[-1, 1] + data[0, 1])/1.5, (data[-1, 2] + data[0, 2])/1.5, 
#          head_width=0.05, head_length=0.05, fc='k', ec='k')
add_arrow_to_line2D(ax2, line,arrowstyle='->')
ax2.grid(True)
ax2.set_xlim(-1,1)
ax2.set_ylim(-1,1)

print(data[0, 1])
# Out:
# -1.03748
